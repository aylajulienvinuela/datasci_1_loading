# %% [markdown]
# <a href="https://colab.research.google.com/github/aylajulienvinuela/datasci_1_loading/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df1 = pd.read_csv('data1_CSV.csv')
df2 = pd.read_csv('data2_CSV.csv')
df3 = pd.read_csv('data3_CSV.csv')

df4 = pd.read_excel('data1_XLSX.xlsx')
df5 = pd.read_excel('data2_XLSX.xlsx')
df6 = pd.read_excel('data3_XLSX.xlsx')

df7 = pd.read_json('data1_JSON.json')
df8 = pd.read_json('data2_JSON.json')
df9 = pd.read_json('data3_JSON.json')

print("DataFrame 1 Shape:", df1.shape)
print("DataFrame 2 Shape:", df2.shape)
print("DataFrame 3 Shape:", df3.shape)
print("DataFrame 4 Shape:", df4.shape)
print("DataFrame 5 Shape:", df5.shape)
print("DataFrame 6 Shape:", df6.shape)
# Out:
# DataFrame 1 Shape: (25000, 11)
# DataFrame 2 Shape: (1, 11)
# DataFrame 3 Shape: (138116, 46)
# DataFrame 4 Shape: (120, 13)
# DataFrame 5 Shape: (5000, 24)
# DataFrame 6 Shape: (31047, 21)

# %%
df1.head(10)
# Out:
#    customer_id        customer_name  customer_age  gender customer_segment  \
# 0  CUST-000001         Donna Miller            54  Female         Consumer
# 1  CUST-000002         Joseph James            61    Male         Consumer
# 2  CUST-000003         Daniel Smith            47    Male         Consumer
# 3  CUST-000004          David Lopez            30    Male              VIP
# 4  CUST-000005         Dakota Davis            55  Female         Consumer
# 5  CUST-000006  Alexander Gutierrez            72  Female         Consumer
# 6  CUST-000007     Adriana Jennings            27  Female          Premium
# 7  CUST-000008         Trevor Brown            40    Male         Consumer
# 8  CUST-000009         Kirsten Ward            59    Male         Consumer
# 9  CUST-000010      Christina Ellis            35  Female              VIP
#
#      customer_city customer_state customer_country   region  \
# 0       Laurenland          Dubai              UAE    South
# ...

# %%
df2.head(10)
# Out:
#    Total Transactions  Total Columns  Total Customers  Total Products Used  \
# 0              138116             46            24911               138116
#
#                  Date Range    Total Revenue    Total Profit  \
# 0  2021-01-01 to 2025-12-31  $177,134,263.74  $76,146,395.76
#
#   Average Order Value  Average Rating Return Rate Cancellation Rate
# 0           $1,282.50            3.68       6.85%             6.08%

# %%
df3.head(10)
# Out:
#      order_id  order_date order_time order_status sales_channel  customer_id  \
# 0  ORD-301242  2023-11-06   16:37:47    Completed    Mobile App  CUST-003102
# 1  ORD-773460  2025-12-24   01:22:36    Completed       Website  CUST-003124
# 2  ORD-449374  2021-07-05   14:24:21    Completed    Mobile App  CUST-012496
# 3  ORD-567636  2023-01-21   07:20:26    Completed  Social Media  CUST-023928
# 4  ORD-820028  2022-05-13   09:46:21    Completed  Social Media  CUST-012730
# 5  ORD-208728  2021-02-10   10:05:47      Pending       Website  CUST-021468
# 6  ORD-686230  2021-05-03   02:55:44    Completed    Mobile App  CUST-023734
# 7  ORD-480470  2022-10-13   21:19:50    Completed    Mobile App  CUST-020081
# 8  ORD-417329  2022-12-06   17:22:52    Completed    Mobile App  CUST-011921
# 9  ORD-961581  2023-09-19   18:38:32    Completed    Mobile App  CUST-016600
#
#      customer_name  customer_age  gender customer_segment  ...  \
# ...

# %%
df4.head(10)
# Out:
#                name  maxEvolutionLevel  elixirCost  \
# 0      Archer Queen                NaN         5.0
# 1           Archers                1.0         3.0
# 2            Arrows                NaN         3.0
# 3       Baby Dragon                1.0         4.0
# 4           Balloon                NaN         5.0
# 5            Bandit                NaN         3.0
# 6  Barbarian Barrel                NaN         2.0
# 7     Barbarian Hut                NaN         6.0
# 8        Barbarians                1.0         5.0
# 9              Bats                1.0         2.0
#
#                                             iconUrls  \
# 0  https://api-assets.clashroyale.com/cards/300/p...
# 1  https://api-assets.clashroyale.com/cards/300/W...
# 2  https://api-assets.clashroyale.com/cards/300/F...
# 3  https://api-assets.clashroyale.com/cards/300/c...
# 4  https://api-assets.clashroyale.com/cards/300/q...
# 5  https://api-assets.clashroyale.com/cards/300/Q...
# ...

# %%
df5.head(10)
# Out:
#   Order No Order Date           Customer Name  \
# 0   4293-1 2014-09-02        Vivek Sundaresam
# 1   5001-1 2015-10-24          Shahid Hopkins
# 2   5004-1 2014-03-13           Dennis Pardue
# 3   5009-1 2013-02-18              Sean Wendt
# 4   5010-1 2014-09-13  Christina Vanderzanden
# 5   5011-1 2013-11-24          Patrick OBrill
# 6   5012-1 2014-09-07            Eugene Moren
# 7   5012-1 2015-01-28       Phillip Flathmann
# 8   5014-1 2014-06-08                John Lee
# 9   5015-1 2014-10-02         Ritsa Hightower
#
#                                              Address       City State  \
# 0                     152 Bunnerong Road,Eastgardens     Sydney   NSW
# 1                      438 Victoria Avenue,Chatswood     Sydney   NSW
# 2                           412 Brunswick St,Fitzroy  Melbourne   VIC
# 3                           145 Ramsay St,Haberfield     Sydney   NSW
# 4                             188 Pitt Street,Sydney     Sydney   NSW
# ...

# %%
df6.head(10)
# Out:
#    index             Order ID  Cust ID Gender  Age Age Group       Date Month  \
# 0      1  171-1029312-3038738  1029312  Women   44    Adults 2022-12-04   Dec
# 1      2  405-2183842-2225946  2183842  Women   29  Teenager 2022-12-04   Dec
# 2      3  171-1641533-8921966  1641533  Women   67    Senior 2022-12-04   Dec
# 3      4  404-7490807-6300351  7490807  Women   20  Teenager 2022-12-04   Dec
# 4      5  403-9293516-4577154  9293516  Women   62    Senior 2022-12-04   Dec
# 5      6  407-1298130-0368305  1298130    Men   49    Adults 2022-12-04   Dec
# 6      7  407-1298130-0368305  1298130  Women   23  Teenager 2022-12-04   Dec
# 7      8  171-5561216-3398711  5561216  Women   70    Senior 2022-12-04   Dec
# 8      9  408-2935263-2935550  2935263  Women   75    Senior 2022-12-04   Dec
# 9     10  404-2648970-9042715  2648970  Women   43    Adults 2022-12-04   Dec
#
#       Status  Channel   ...       Category Size Qty  currency Amount  \
# ...

# %%
df7.head(10)
# Out:
#                                                    generated_at  \
# included                       2026-09-19 05:40:30.462000+00:00
# rows_from_neon                 2026-09-19 05:40:30.462000+00:00
# legacy_cutoff                  2026-09-19 05:40:30.462000+00:00
# from                           2026-09-19 05:40:30.462000+00:00
# to                             2026-09-19 05:40:30.462000+00:00
# dld_sales_transactions.csv     2026-09-19 05:40:30.462000+00:00
# dld_sales_transactions.parquet 2026-09-19 05:40:30.462000+00:00
#
#                                source_manifest_downloaded_at  \
# included                                          2026-06-11
# rows_from_neon                                    2026-06-11
# legacy_cutoff                                     2026-06-11
# from                                              2026-06-11
# to                                                2026-06-11
# dld_sales_transactions.csv                        2026-06-11
# ...

# %%
df8.head(10)
# Out:
#                                                                     source_dir  \
# submissions: both truth values seen              /kaggle/input/deleted-dataset
# marked_selected: both truth values seen          /kaggle/input/deleted-dataset
# teams: benchmark rows exist                      /kaggle/input/deleted-dataset
# competitions awarding medals                     /kaggle/input/deleted-dataset
# submission dates parsed, pct                     /kaggle/input/deleted-dataset
# deadlines parsed, pct                            /kaggle/input/deleted-dataset
# choosable submissions                            /kaggle/input/deleted-dataset
# competitions with metric still a bare id, pct    /kaggle/input/deleted-dataset
# boards reproduced exactly, pct                   /kaggle/input/deleted-dataset
# submissions with the board's arrival known, pct  /kaggle/input/deleted-dataset
#
#                                                                  built_at  \
# ...

# %%
df9.head(10)
# Out:
#                                            item_id  \
# 0                             MCD_BURG_Big_Mac_325
# 1         MCD_BURG_Quarter_Pounder_with_Cheese_180
# 2                        MCD_BURG_Cheeseburger_723
# 3                 MCD_BURG_Double_Cheeseburger_771
# 4                            MCD_BURG_McDouble_710
# 5                           MCD_BURG_Hamburger_991
# 6                      MCD_BURG_Bacon_McDouble_878
# 7  MCD_BURG_Quarter_Pounder_with_Cheese_Deluxe_330
# 8                  MCD_BURG_Big_Mac_with_Bacon_348
# 9  MCD_BURG_Double_Quarter_Pounder_with_Cheese_995
#
#                             item_name category  \
# 0                             Big Mac  Burgers
# 1         Quarter Pounder with Cheese  Burgers
# 2                        Cheeseburger  Burgers
# 3                 Double Cheeseburger  Burgers
# 4                            McDouble  Burgers
# 5                           Hamburger  Burgers
# 6                      Bacon McDouble  Burgers
# ...

# %% [markdown]
# # CSV:
#
# ## Dataset 1-
#
# **customer_id**; the numerical ID associated with the customer
#
# **customer_name**; the name of the customer
#
# **customer_age**: the age of the customer
#
# **gender**; the gender of the customer
#
# **customer_segment**; the segment the customer falls into
#
# **customer_city**; the city the customer is located in
#
# **customer_state**; the state the customer is located in
#
# **customer_country**; the country the customer is located in
#
# **region**; the region the customer is located in
#
# **customer_postal_code**; the postal code associated with the location of the customer
#
# **customer_acquisition_cos**; the cost to gain the new customer
#
# ## Dataset 2-
#
# **Total Transactions**; total number of transactions
#
# **Total Columns**; total number of columns
#
# **Total Customers**; total number of customers
#
# **Total Products Used**; total number of products used
#
# **Date Range**; date range the data was collected
#
# **Total Revenue**; the total revenue in US dollars
#
# **Total Profit**; the total profit in US dollars
#
# **Average Order Value**; the average value of an order
#
# **Average Rating**; the average order rating out of 5
#
# **Return Rate**; the percentage of returns
#
# **Cancellation Rate**; the percentage of cancellattions
#
# ## Dataset 3-
# **order_id**; the id number associated with the order
#
# **order_date**; the date associated with the order purchase
#
# **order_time**; the time associated with the order purchase
#
# **order_status**: the status of the order
#
# **sales_channel**; the channel in which the order was completed
#
# **customer_id**; the id number of the customer
#
# **customer_name**; the name of the customer
#
# **customer_age**; the age of the customer
#
# **gender**; the gender of the custome
#
# **customer_segment**; the segment the customer falls into
#
# **discount_amount**; the discount number on the order
#
# **tax_amount**; the tax amount on the order
#
# **shipping_cost**; the shipping cost on the order
#
# **net_sale**; actual revenue from order
#
# **product_cost**: cost of product
#
# **profit**; profit from order
#
# **profit_margin_percentage**; percentage of profit margin
#
# **customer_lifetime_value**; total net profit from customer
#
# **is_repeat_customer**; determines if the cusomer had purchased more than once
#
# **customer_order_count**; order amount from customer
#
# #XLSX:
#
# ## Dataset 1-
# **name**; clash royale character name
#
# **maxEvolutionLevel**; maximum evolution level for the character
#
# **elixirCost**; cost of the elixir for the character
#
# **iconUrls**; the URL associated with character icon
#
# **evolutionIcons**; the icons associated with the character evolution
#
# **rarity**; the rarity of the character
#
# **type**; the character type
#
# **mobility**; the mobility of the character
#
# **targets**; character of target
#
# **attack_type**; the attack type of the character
#
# **groupCard**; the group card of the character
#
# **usage**; the usage of the character
#
# **hitpoints**; the character's hitpoints
#
# ##Dataset 2-
# **Order No**;	The number of the order
#
# **Order Date**; The date of the order
#
# **Customer Name**; The name of the customer
#
# **Address**;	The address of the customer
#
# **City**; The city the customer is located in
#
# **State**; The state the customer is located in
#
# **Customer Type**; The type of customer
#
# **Account Manager**; The manager of the account
#
# **Order Priority**; The priority of the order
#
# **Product Name**; The name of the ordered product
#
# **Cost Price**; The internal cost of the product
#
# **Retail Price**; The retail cost of the product
#
# **Profit Margin**; The margin of product for the product
#
# **Order Quantity**; The quantity of products in one order
#
# **Sub Total	Discount %**; The discount percentage of the total
#
# **Discount $**; The discount amount in US dollars
#
# **Order Total**; The total cost of the order, in US dollars
#
# **Shipping Cost	Total**; The total shipping cost
#
# ##Dataset 3-
# **index**; The row number
#
# **Order ID**; The numerical ID of the order
#
# **Cust ID**; The numerical ID of the customer
#
# **Gender**; The gender of the customer
#
# **Age**; The age of the customer
#
# **Age Group**; The age group the customer has fallen into
#
# **Date**; The date of the order
#
# **Month**; The month the order was completed
#
# **Status**; The order status
#
# **Channel**; The channel in which the order was purchased
#
# **Category**; The category of the purchase
#
# **Size**; The purchase size
#
# **Qty**; The quantity of the order
#
# **currency**; The currency used to purchase the order
#
# **Amount**; The cost of the order
#
# **ship-city**; The city the order ships to
#
# **ship-state**; The state the order ships to
#
# **ship-postal-code**; The postal code the order ships to
#
# **\/**; Determines whether the order is IN
#
# **B2B**; Determines if the order is business to business
#
# # JSON:
#
# ##Dataset 1-
# **generated_at**; The date the manifest was generated
#
# **source_manifest_downloaded_at**; The source the manifest was downloaded at
#
# **source_file**; The source file
#
# **source_sha256**; The technical label used to identify the unique digital fingerprint of the original source file
#
# **methodology_version**; The version of methodology
#
# **live_extension**; The live extension
#
# **row_count**; The count of rows
#
# **clean_row_count**: The count of clean rows
#
# **coverage	outputs**; The coverage outputs
#
# ##Dataset 2-
# **source_dir**; The source directory
#
# **built_at**; The time it was built at
#
# **duckdb_version**; The version of duckdb used
#
# **min_teams**; The minimum teams
#
# **max_meaningful_slots**; The maximum meaningful slots
#
# **checks**; The amount of checks
#
# **source_latest_submission**;	Time of the latest submission
#
# **source_submission_rows**; The number of rows in the source submission
#
# **competitions_in_scope**; The in scope competitions
#
# **competitions_below_min_teams**; The competitions below the minimum
#
# **files	headline**; The files headline
#
# ##Dataset 3-
# **item_id**; The id associated with the item
#
# **item_name**; The name of the item
#
# **category**; The category of the item
#
# **description**; The description of the item
#
# **price_usd**; The price of the item in US dollars
#
# **calories**; The calories of the item
#
# **calories_from_fat**; The calories of the item that come from fat
#
# **total_fat_g**; The total fat in grams of the item
#
# **saturated_fat_g**; The total saturated fat in grams of the item
#
# **trans_fat_g**; The total trans fat in grams of the item
#
# **has_sizes**; Determines if it has sizes
#
# **is_popular**; Determines if it is a popular item
#
# **is_limited_time**; Determines if it is a limited item
#
# **is_nationwide**; Determines if it is available nationwide
#
# **serving_size**; The serving size of the item
#
# **prep_time_minutes**; The prep time of the item in minutes
#
# **price_per_calorie**; The price per calorie of the item
#
# **protein_per_dollar**; The protein per dollar of the item
#
# **calorie_density**; The calorie density of the item
#
# **price_history**; The price history of the item
